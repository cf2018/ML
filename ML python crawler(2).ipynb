# %%
import requests
import simplejson
import unidecode
import operator
import json
import sys
from IPython.core.display import display, HTML
import pandas as pd
from collections import OrderedDict
from datetime import date
import random
from ml import *

pd.set_option('display.max_colwidth', -1)
display.border = 2
df_final = pd.DataFrame.from_dict([])
category = 'MLA1071'  # juegos y juguetes
categories =  { "id": "MLA5725", "name": "Accesorios para Vehículos" }, { "id": "MLA1403", "name": "Alimentos y Bebidas" }, { "id": "MLA1071", "name": "Animales y Mascotas" }, { "id": "MLA1367", "name": "Antigüedades" }, { "id": "MLA1368", "name": "Arte y Artesanías" }, { "id": "MLA1743", "name": "Autos, Motos y Otros" }, { "id": "MLA1384", "name": "Bebés" }, { "id": "MLA1246", "name": "Belleza y Cuidado Personal" }, { "id": "MLA1039", "name": "Cámaras y Accesorios" }, { "id": "MLA1051", "name": "Celulares y Teléfonos" }, { "id": "MLA1798", "name": "Coleccionables y Hobbies" }, { "id": "MLA1648", "name": "Computación" }, { "id": "MLA1144", "name": "Consolas y Videojuegos" }, { "id": "MLA1276", "name": "Deportes y Fitness" }, { "id": "MLA5726", "name": "Electrodomésticos y Aires Ac." }, { "id": "MLA1000", "name": "Electrónica, Audio y Video" }, { "id": "MLA2547", "name": "Entradas para Eventos" }, { "id": "MLA407134", "name": "Herramientas y Construcción" }, { "id": "MLA1574", "name": "Hogar, Muebles y Jardín" }, { "id": "MLA1499", "name": "Industrias y Oficinas" }, { "id": "MLA1459", "name": "Inmuebles" }, { "id": "MLA1182", "name": "Instrumentos Musicales" }, { "id": "MLA3937", "name": "Joyas y Relojes" }, { "id": "MLA1132", "name": "Juegos y Juguetes" }, { "id": "MLA3025", "name": "Libros, Revistas y Comics" }, { "id": "MLA1168", "name": "Música, Películas y Series" }, { "id": "MLA1430", "name": "Ropa y Accesorios" }, { "id": "MLA409431", "name": "Salud y Equipamiento Médico" }, { "id": "MLA1540", "name": "Servicios" }, { "id": "MLA1953", "name": "Otras categorías"}

# %% [markdown]
# https://api.mercadolibre.com/sites/MLA/categories
# https://api.mercadolibre.com/sites/MLA/search?q=fabrica&category=MLA1403

# %%
###############PARAMETERS#######################################################
file = open("palabras_3_letras.txt", "r")

# PRODUCT FROM FILE OR LIST VARIABLE
lines = file.readlines()
#lines = ('led','fabrica')

min_price_list = (1,2000,10000)#,3000,8000,16000)
max_price_list = (2000,10000,20000)#,3000,8000,16000,240000)
other_locations = "Expeleta" #FILTER LIST
percentage_max_sell = "0.05" #FILTER % BELOW MAX SOLD
sell_condition = "new" #"old" # USED o NEW
min_sell = 1 # MINIMUM SELL FOR LOCATION
#############END PARAMETERS#####################################################


for product in lines:
    product = random.choice(lines)
    for category in categories:
        print(product," category : ",category['name']) # PRODUCT NAME SEARCHED
        df_temp = display_product(product,min_price_list,max_price_list,sell_condition,percentage_max_sell,category['id'],500000)
        if (len(df_temp)>0):
            df_final = df_final.append(df_temp)
        if ( len(df_final) == 0):
            df_final = df_temp
        print ("df_final length is :",len(df_final))
        df_final.to_csv('df_final.csv')
    if (len(df_final)> 2000):
        break
# Out:
# Non
#   category :  Accesorios para Vehículos
# df_final length is : 0
# Non
#   category :  Alimentos y Bebidas
# df_final length is : 0
# Non
#   category :  Animales y Mascotas
# df_final length is : 0
# Non
#   category :  Antigüedades
# df_final length is : 0
# Non
#   category :  Arte y Artesanías
# df_final length is : 0
# Non
#   category :  Autos, Motos y Otros
# df_final length is : 0
# Non
#   category :  Bebés
# df_final length is : 0
# Non
#   category :  Belleza y Cuidado Personal
# df_final length is : 2
# Non
#   category :  Cámaras y Accesorios
# df_final length is : 2
# Non
#   category :  Celulares y Teléfonos
# df_final length is : 2
# Non
#   category :  Coleccionables y Hobbies
# df_final length is : 2
# Non
#   category :  Computación
# df_final length is : 2
# Non
#   category :  Consolas y Videojuegos
# df_final length is : 2
# Non
#   category :  Deportes y Fitness
# df_final length is : 2
# Non
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 2
# Non
#   category :  Electrónica, Audio y Video
# df_final length is : 2
# Non
#   category :  Entradas para Eventos
# df_final length is : 2
# Non
#   category :  Herramientas y Construcción
# df_final length is : 2
# Non
#   category :  Hogar, Muebles y Jardín
# df_final length is : 2
# Non
#   category :  Industrias y Oficinas
# df_final length is : 2
# Non
#   category :  Inmuebles
# df_final length is : 2
# Non
#   category :  Instrumentos Musicales
# df_final length is : 2
# Non
#   category :  Joyas y Relojes
# df_final length is : 2
# Non
#   category :  Juegos y Juguetes
# df_final length is : 2
# Non
#   category :  Libros, Revistas y Comics
# df_final length is : 2
# Non
#   category :  Música, Películas y Series
# df_final length is : 2
# Non
#   category :  Ropa y Accesorios
# df_final length is : 2
# Non
#   category :  Salud y Equipamiento Médico
# df_final length is : 2
# Non
#   category :  Servicios
# df_final length is : 2
# Non
#   category :  Otras categorías
# df_final length is : 2
# Ton
#   category :  Accesorios para Vehículos
# df_final length is : 2
# Ton
#   category :  Alimentos y Bebidas
# df_final length is : 2
# Ton
#   category :  Animales y Mascotas
# df_final length is : 2
# Ton
#   category :  Antigüedades
# df_final length is : 3
# Ton
#   category :  Arte y Artesanías
# df_final length is : 3
# Ton
#   category :  Autos, Motos y Otros
# df_final length is : 3
# Ton
#   category :  Bebés
# df_final length is : 4
# Ton
#   category :  Belleza y Cuidado Personal
# df_final length is : 5
# Ton
#   category :  Cámaras y Accesorios
# df_final length is : 5
# Ton
#   category :  Celulares y Teléfonos
# df_final length is : 5
# Ton
#   category :  Coleccionables y Hobbies
# df_final length is : 5
# Ton
#   category :  Computación
# df_final length is : 6
# Ton
#   category :  Consolas y Videojuegos
# df_final length is : 7
# Ton
#   category :  Deportes y Fitness
# df_final length is : 8
# Ton
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 8
# Ton
#   category :  Electrónica, Audio y Video
# df_final length is : 8
# Ton
#   category :  Entradas para Eventos
# df_final length is : 8
# Ton
#   category :  Herramientas y Construcción
# df_final length is : 11
# Ton
#   category :  Hogar, Muebles y Jardín
# df_final length is : 22
# Ton
#   category :  Industrias y Oficinas
# df_final length is : 22
# Ton
#   category :  Inmuebles
# df_final length is : 22
# Ton
#   category :  Instrumentos Musicales
# df_final length is : 23
# Ton
#   category :  Joyas y Relojes
# df_final length is : 23
# Ton
#   category :  Juegos y Juguetes
# df_final length is : 23
# Ton
#   category :  Libros, Revistas y Comics
# df_final length is : 23
# Ton
#   category :  Música, Películas y Series
# df_final length is : 23
# Ton
#   category :  Ropa y Accesorios
# df_final length is : 24
# Ton
#   category :  Salud y Equipamiento Médico
# df_final length is : 25
# Ton
#   category :  Servicios
# df_final length is : 25
# Ton
#   category :  Otras categorías
# df_final length is : 25
# Vas
#   category :  Accesorios para Vehículos
# df_final length is : 26
# Vas
#   category :  Alimentos y Bebidas
# df_final length is : 26
# Vas
#   category :  Animales y Mascotas
# df_final length is : 26
# Vas
#   category :  Antigüedades
# df_final length is : 26
# Vas
#   category :  Arte y Artesanías
# df_final length is : 26
# Vas
#   category :  Autos, Motos y Otros
# df_final length is : 26
# Vas
#   category :  Bebés
# df_final length is : 26
# Vas
#   category :  Belleza y Cuidado Personal
# df_final length is : 26
# Vas
#   category :  Cámaras y Accesorios
# df_final length is : 26
# Vas
#   category :  Celulares y Teléfonos
# df_final length is : 26
# Vas
#   category :  Coleccionables y Hobbies
# df_final length is : 26
# Vas
#   category :  Computación
# df_final length is : 26
# Vas
#   category :  Consolas y Videojuegos
# df_final length is : 26
# Vas
#   category :  Deportes y Fitness
# df_final length is : 26
# Vas
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 26
# Vas
#   category :  Electrónica, Audio y Video
# df_final length is : 26
# Vas
#   category :  Entradas para Eventos
# df_final length is : 26
# Vas
#   category :  Herramientas y Construcción
# df_final length is : 26
# Vas
#   category :  Hogar, Muebles y Jardín
# df_final length is : 26
# Vas
#   category :  Industrias y Oficinas
# df_final length is : 26
# Vas
#   category :  Inmuebles
# df_final length is : 26
# Vas
#   category :  Instrumentos Musicales
# df_final length is : 26
# Vas
#   category :  Joyas y Relojes
# df_final length is : 26
# Vas
#   category :  Juegos y Juguetes
# df_final length is : 26
# Vas
#   category :  Libros, Revistas y Comics
# df_final length is : 26
# Vas
#   category :  Música, Películas y Series
# df_final length is : 26
# Vas
#   category :  Ropa y Accesorios
# df_final length is : 26
# Vas
#   category :  Salud y Equipamiento Médico
# df_final length is : 26
# Vas
#   category :  Servicios
# df_final length is : 26
# Vas
#   category :  Otras categorías
# df_final length is : 26
# Aba
#   category :  Accesorios para Vehículos
# df_final length is : 26
# Aba
#   category :  Alimentos y Bebidas
# df_final length is : 26
# Aba
#   category :  Animales y Mascotas
# df_final length is : 26
# Aba
#   category :  Antigüedades
# df_final length is : 26
# Aba
#   category :  Arte y Artesanías
# df_final length is : 26
# Aba
#   category :  Autos, Motos y Otros
# df_final length is : 26
# Aba
#   category :  Bebés
# df_final length is : 26
# Aba
#   category :  Belleza y Cuidado Personal
# df_final length is : 26
# Aba
#   category :  Cámaras y Accesorios
# df_final length is : 26
# Aba
#   category :  Celulares y Teléfonos
# df_final length is : 26
# Aba
#   category :  Coleccionables y Hobbies
# df_final length is : 26
# Aba
#   category :  Computación
# df_final length is : 26
# Aba
#   category :  Consolas y Videojuegos
# df_final length is : 26
# Aba
#   category :  Deportes y Fitness
# df_final length is : 26
# Aba
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 26
# Aba
#   category :  Electrónica, Audio y Video
# df_final length is : 26
# Aba
#   category :  Entradas para Eventos
# df_final length is : 26
# Aba
#   category :  Herramientas y Construcción
# df_final length is : 26
# Aba
#   category :  Hogar, Muebles y Jardín
# df_final length is : 26
# Aba
#   category :  Industrias y Oficinas
# df_final length is : 26
# Aba
#   category :  Inmuebles
# df_final length is : 26
# Aba
#   category :  Instrumentos Musicales
# df_final length is : 26
# Aba
#   category :  Joyas y Relojes
# df_final length is : 26
# Aba
#   category :  Juegos y Juguetes
# df_final length is : 26
# Aba
#   category :  Libros, Revistas y Comics
# df_final length is : 26
# Aba
#   category :  Música, Películas y Series
# df_final length is : 26
# Aba
#   category :  Ropa y Accesorios
# df_final length is : 26
# Aba
#   category :  Salud y Equipamiento Médico
# df_final length is : 26
# Aba
#   category :  Servicios
# df_final length is : 26
# Aba
#   category :  Otras categorías
# df_final length is : 26
# Yes
#   category :  Accesorios para Vehículos
# df_final length is : 26
# Yes
#   category :  Alimentos y Bebidas
# df_final length is : 26
# Yes
#   category :  Animales y Mascotas
# df_final length is : 26
# Yes
#   category :  Antigüedades
# df_final length is : 26
# Yes
#   category :  Arte y Artesanías
# df_final length is : 26
# Yes
#   category :  Autos, Motos y Otros
# df_final length is : 26
# Yes
#   category :  Bebés
# df_final length is : 26
# Yes
#   category :  Belleza y Cuidado Personal
# df_final length is : 26
# Yes
#   category :  Cámaras y Accesorios
# df_final length is : 26
# Yes
#   category :  Celulares y Teléfonos
# df_final length is : 26
# Yes
#   category :  Coleccionables y Hobbies
# df_final length is : 26
# Yes
#   category :  Computación
# df_final length is : 26
# Yes
#   category :  Consolas y Videojuegos
# df_final length is : 26
# Yes
#   category :  Deportes y Fitness
# df_final length is : 26
# Yes
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 26
# Yes
#   category :  Electrónica, Audio y Video
# df_final length is : 26
# Yes
#   category :  Entradas para Eventos
# df_final length is : 26
# Yes
#   category :  Herramientas y Construcción
# df_final length is : 26
# Yes
#   category :  Hogar, Muebles y Jardín
# df_final length is : 26
# Yes
#   category :  Industrias y Oficinas
# df_final length is : 26
# Yes
#   category :  Inmuebles
# df_final length is : 26
# Yes
#   category :  Instrumentos Musicales
# df_final length is : 26
# Yes
#   category :  Joyas y Relojes
# df_final length is : 26
# Yes
#   category :  Juegos y Juguetes
# df_final length is : 26
# Yes
#   category :  Libros, Revistas y Comics
# df_final length is : 26
# Yes
#   category :  Música, Películas y Series
# df_final length is : 26
# Yes
#   category :  Ropa y Accesorios
# df_final length is : 26
# Yes
#   category :  Salud y Equipamiento Médico
# df_final length is : 26
# Yes
#   category :  Servicios
# df_final length is : 26
# Yes
#   category :  Otras categorías
# df_final length is : 26
# Bla
#   category :  Accesorios para Vehículos
# df_final length is : 26
# Bla
#   category :  Alimentos y Bebidas
# df_final length is : 26
# Bla
#   category :  Animales y Mascotas
# df_final length is : 26
# Bla
#   category :  Antigüedades
# df_final length is : 26
# Bla
#   category :  Arte y Artesanías
# df_final length is : 26
# Bla
#   category :  Autos, Motos y Otros
# df_final length is : 26
# Bla
#   category :  Bebés
# df_final length is : 26
# Bla
#   category :  Belleza y Cuidado Personal
# df_final length is : 26
# Bla
#   category :  Cámaras y Accesorios
# df_final length is : 26
# Bla
#   category :  Celulares y Teléfonos
# df_final length is : 26
# Bla
#   category :  Coleccionables y Hobbies
# df_final length is : 26
# Bla
#   category :  Computación
# df_final length is : 26
# Bla
#   category :  Consolas y Videojuegos
# df_final length is : 26
# Bla
#   category :  Deportes y Fitness
# df_final length is : 26
# Bla
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 29
# Bla
#   category :  Electrónica, Audio y Video
# df_final length is : 30
# Bla
#   category :  Entradas para Eventos
# df_final length is : 30
# Bla
#   category :  Herramientas y Construcción
# df_final length is : 31
# Bla
#   category :  Hogar, Muebles y Jardín
# df_final length is : 32
# Bla
#   category :  Industrias y Oficinas
# df_final length is : 32
# Bla
#   category :  Inmuebles
# df_final length is : 32
# Bla
#   category :  Instrumentos Musicales
# df_final length is : 32
# Bla
#   category :  Joyas y Relojes
# df_final length is : 32
# Bla
#   category :  Juegos y Juguetes
# df_final length is : 32
# Bla
#   category :  Libros, Revistas y Comics
# df_final length is : 32
# Bla
#   category :  Música, Películas y Series
# df_final length is : 32
# Bla
#   category :  Ropa y Accesorios
# df_final length is : 32
# Bla
#   category :  Salud y Equipamiento Médico
# df_final length is : 32
# Bla
#   category :  Servicios
# df_final length is : 32
# Bla
#   category :  Otras categorías
# df_final length is : 32
# Ple
#   category :  Accesorios para Vehículos
# df_final length is : 32
# Ple
#   category :  Alimentos y Bebidas
# df_final length is : 32
# Ple
#   category :  Animales y Mascotas
# df_final length is : 32
# Ple
#   category :  Antigüedades
# df_final length is : 32
# Ple
#   category :  Arte y Artesanías
# df_final length is : 33
# Ple
#   category :  Autos, Motos y Otros
# df_final length is : 33
# Ple
#   category :  Bebés
# df_final length is : 33
# Ple
#   category :  Belleza y Cuidado Personal
# df_final length is : 33
# Ple
#   category :  Cámaras y Accesorios
# df_final length is : 33
# Ple
#   category :  Celulares y Teléfonos
# df_final length is : 33
# Ple
#   category :  Coleccionables y Hobbies
# df_final length is : 33
# Ple
#   category :  Computación
# df_final length is : 33
# Ple
#   category :  Consolas y Videojuegos
# df_final length is : 33
# Ple
#   category :  Deportes y Fitness
# df_final length is : 33
# Ple
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 34
# Ple
#   category :  Electrónica, Audio y Video
# df_final length is : 34
# Ple
#   category :  Entradas para Eventos
# df_final length is : 34
# Ple
#   category :  Herramientas y Construcción
# df_final length is : 34
# Ple
#   category :  Hogar, Muebles y Jardín
# df_final length is : 35
# Ple
#   category :  Industrias y Oficinas
# df_final length is : 35
# Ple
#   category :  Inmuebles
# df_final length is : 35
# Ple
#   category :  Instrumentos Musicales
# df_final length is : 35
# Ple
#   category :  Joyas y Relojes
# df_final length is : 35
# Ple
#   category :  Juegos y Juguetes
# df_final length is : 35
# Ple
#   category :  Libros, Revistas y Comics
# df_final length is : 35
# Ple
#   category :  Música, Películas y Series
# df_final length is : 35
# Ple
#   category :  Ropa y Accesorios
# df_final length is : 35
# Ple
#   category :  Salud y Equipamiento Médico
# df_final length is : 36
# Ple
#   category :  Servicios
# df_final length is : 36
# Ple
#   category :  Otras categorías
# df_final length is : 36
# Ches
#   category :  Accesorios para Vehículos
# df_final length is : 36
# Ches
#   category :  Alimentos y Bebidas
# df_final length is : 36
# Ches
#   category :  Animales y Mascotas
# df_final length is : 36
# Ches
#   category :  Antigüedades
# df_final length is : 36
# Ches
#   category :  Arte y Artesanías
# df_final length is : 36
# Ches
#   category :  Autos, Motos y Otros
# df_final length is : 36
# Ches
#   category :  Bebés
# df_final length is : 36
# Ches
#   category :  Belleza y Cuidado Personal
# df_final length is : 36
# Ches
#   category :  Cámaras y Accesorios
# df_final length is : 36
# Ches
#   category :  Celulares y Teléfonos
# df_final length is : 36
# Ches
#   category :  Coleccionables y Hobbies
# df_final length is : 36
# Ches
#   category :  Computación
# df_final length is : 36
# Ches
#   category :  Consolas y Videojuegos
# df_final length is : 36
# Ches
#   category :  Deportes y Fitness
# df_final length is : 36
# Ches
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 36
# Ches
#   category :  Electrónica, Audio y Video
# df_final length is : 36
# Ches
#   category :  Entradas para Eventos
# df_final length is : 36
# Ches
#   category :  Herramientas y Construcción
# df_final length is : 36
# Ches
#   category :  Hogar, Muebles y Jardín
# df_final length is : 36
# Ches
#   category :  Industrias y Oficinas
# df_final length is : 36
# Ches
#   category :  Inmuebles
# df_final length is : 36
# Ches
#   category :  Instrumentos Musicales
# df_final length is : 36
# Ches
#   category :  Joyas y Relojes
# df_final length is : 36
# Ches
#   category :  Juegos y Juguetes
# df_final length is : 36
# Ches
#   category :  Libros, Revistas y Comics
# df_final length is : 36
# Ches
#   category :  Música, Películas y Series
# df_final length is : 36
# Ches
#   category :  Ropa y Accesorios
# df_final length is : 36
# Ches
#   category :  Salud y Equipamiento Médico
# df_final length is : 36
# Ches
#   category :  Servicios
# df_final length is : 36
# Ches
#   category :  Otras categorías
# df_final length is : 36
# Lay
#   category :  Accesorios para Vehículos
# df_final length is : 36
# Lay
#   category :  Alimentos y Bebidas
# df_final length is : 36
# Lay
#   category :  Animales y Mascotas
# df_final length is : 36
# Lay
#   category :  Antigüedades
# df_final length is : 36
# Lay
#   category :  Arte y Artesanías
# df_final length is : 36
# Lay
#   category :  Autos, Motos y Otros
# df_final length is : 36
# Lay
#   category :  Bebés
# df_final length is : 36
# Lay
#   category :  Belleza y Cuidado Personal
# df_final length is : 36
# Lay
#   category :  Cámaras y Accesorios
# df_final length is : 36
# Lay
#   category :  Celulares y Teléfonos
# df_final length is : 36
# Lay
#   category :  Coleccionables y Hobbies
# df_final length is : 36
# Lay
#   category :  Computación
# df_final length is : 36
# Lay
#   category :  Consolas y Videojuegos
# df_final length is : 36
# Lay
#   category :  Deportes y Fitness
# df_final length is : 36
# Lay
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 36
# Lay
#   category :  Electrónica, Audio y Video
# df_final length is : 36
# Lay
#   category :  Entradas para Eventos
# df_final length is : 36
# Lay
#   category :  Herramientas y Construcción
# df_final length is : 36
# Lay
#   category :  Hogar, Muebles y Jardín
# df_final length is : 36
# Lay
#   category :  Industrias y Oficinas
# df_final length is : 36
# Lay
#   category :  Inmuebles
# df_final length is : 36
# Lay
#   category :  Instrumentos Musicales
# df_final length is : 36
# Lay
#   category :  Joyas y Relojes
# df_final length is : 36
# Lay
#   category :  Juegos y Juguetes
# df_final length is : 36
# Lay
#   category :  Libros, Revistas y Comics
# df_final length is : 36
# Lay
#   category :  Música, Películas y Series
# df_final length is : 36
# Lay
#   category :  Ropa y Accesorios
# df_final length is : 36
# Lay
#   category :  Salud y Equipamiento Médico
# df_final length is : 36
# Lay
#   category :  Servicios
# df_final length is : 36
# Lay
#   category :  Otras categorías
# df_final length is : 36
# Ble
#   category :  Accesorios para Vehículos
# df_final length is : 36
# Ble
#   category :  Alimentos y Bebidas
# df_final length is : 36
# Ble
#   category :  Animales y Mascotas
# df_final length is : 36
# Ble
#   category :  Antigüedades
# df_final length is : 36
# Ble
#   category :  Arte y Artesanías
# df_final length is : 36
# Ble
#   category :  Autos, Motos y Otros
# df_final length is : 36
# Ble
#   category :  Bebés
# df_final length is : 37
# Ble
#   category :  Belleza y Cuidado Personal
# df_final length is : 37
# Ble
#   category :  Cámaras y Accesorios
# df_final length is : 37
# Ble
#   category :  Celulares y Teléfonos
# df_final length is : 37
# Ble
#   category :  Coleccionables y Hobbies
# df_final length is : 37
# Ble
#   category :  Computación
# df_final length is : 37
# Ble
#   category :  Consolas y Videojuegos
# df_final length is : 37
# Ble
#   category :  Deportes y Fitness
# df_final length is : 37
# Ble
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 37
# Ble
#   category :  Electrónica, Audio y Video
# df_final length is : 37
# Ble
#   category :  Entradas para Eventos
# df_final length is : 37
# Ble
#   category :  Herramientas y Construcción
# df_final length is : 37
# Ble
#   category :  Hogar, Muebles y Jardín
# df_final length is : 37
# Ble
#   category :  Industrias y Oficinas
# df_final length is : 37
# Ble
#   category :  Inmuebles
# df_final length is : 37
# Ble
#   category :  Instrumentos Musicales
# df_final length is : 37
# Ble
#   category :  Joyas y Relojes
# df_final length is : 37
# Ble
#   category :  Juegos y Juguetes
# df_final length is : 37
# Ble
#   category :  Libros, Revistas y Comics
# df_final length is : 37
# Ble
#   category :  Música, Películas y Series
# df_final length is : 37
# Ble
#   category :  Ropa y Accesorios
# df_final length is : 37
# Ble
#   category :  Salud y Equipamiento Médico
# df_final length is : 37
# Ble
#   category :  Servicios
# df_final length is : 37
# Ble
#   category :  Otras categorías
# df_final length is : 37
# Ños
#   category :  Accesorios para Vehículos
# df_final length is : 37
# Ños
#   category :  Alimentos y Bebidas
# df_final length is : 37
# Ños
#   category :  Animales y Mascotas
# df_final length is : 37
# Ños
#   category :  Antigüedades
# df_final length is : 37
# Ños
#   category :  Arte y Artesanías
# df_final length is : 37
# Ños
#   category :  Autos, Motos y Otros
# df_final length is : 37
# Ños
#   category :  Bebés
# df_final length is : 37
# Ños
#   category :  Belleza y Cuidado Personal
# df_final length is : 37
# Ños
#   category :  Cámaras y Accesorios
# df_final length is : 37
# Ños
#   category :  Celulares y Teléfonos
# df_final length is : 37
# Ños
#   category :  Coleccionables y Hobbies
# df_final length is : 37
# Ños
#   category :  Computación
# df_final length is : 37
# Ños
#   category :  Consolas y Videojuegos
# df_final length is : 37
# Ños
#   category :  Deportes y Fitness
# df_final length is : 37
# Ños
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 37
# Ños
#   category :  Electrónica, Audio y Video
# df_final length is : 37
# Ños
#   category :  Entradas para Eventos
# df_final length is : 37
# Ños
#   category :  Herramientas y Construcción
# df_final length is : 37
# Ños
#   category :  Hogar, Muebles y Jardín
# df_final length is : 38
# Ños
#   category :  Industrias y Oficinas
# df_final length is : 38
# Ños
#   category :  Inmuebles
# df_final length is : 38
# Ños
#   category :  Instrumentos Musicales
# df_final length is : 38
# Ños
#   category :  Joyas y Relojes
# df_final length is : 38
# Ños
#   category :  Juegos y Juguetes
# df_final length is : 38
# Ños
#   category :  Libros, Revistas y Comics
# df_final length is : 38
# Ños
#   category :  Música, Películas y Series
# df_final length is : 38
# Ños
#   category :  Ropa y Accesorios
# df_final length is : 38
# Ños
#   category :  Salud y Equipamiento Médico
# df_final length is : 38
# Ños
#   category :  Servicios
# df_final length is : 38
# Ños
#   category :  Otras categorías
# df_final length is : 38
# Aña
#   category :  Accesorios para Vehículos
# df_final length is : 38
# Aña
#   category :  Alimentos y Bebidas
# df_final length is : 38
# Aña
#   category :  Animales y Mascotas
# df_final length is : 38
# Aña
#   category :  Antigüedades
# df_final length is : 38
# Aña
#   category :  Arte y Artesanías
# df_final length is : 38
# Aña
#   category :  Autos, Motos y Otros
# df_final length is : 38
# Aña
#   category :  Bebés
# df_final length is : 38
# Aña
#   category :  Belleza y Cuidado Personal
# df_final length is : 38
# Aña
#   category :  Cámaras y Accesorios
# df_final length is : 38
# Aña
#   category :  Celulares y Teléfonos
# df_final length is : 38
# Aña
#   category :  Coleccionables y Hobbies
# df_final length is : 38
# Aña
#   category :  Computación
# df_final length is : 38
# Aña
#   category :  Consolas y Videojuegos
# df_final length is : 38
# Aña
#   category :  Deportes y Fitness
# df_final length is : 38
# Aña
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 38
# Aña
#   category :  Electrónica, Audio y Video
# df_final length is : 38
# Aña
#   category :  Entradas para Eventos
# df_final length is : 38
# Aña
#   category :  Herramientas y Construcción
# df_final length is : 38
# Aña
#   category :  Hogar, Muebles y Jardín
# df_final length is : 39
# Aña
#   category :  Industrias y Oficinas
# df_final length is : 39
# Aña
#   category :  Inmuebles
# df_final length is : 39
# Aña
#   category :  Instrumentos Musicales
# df_final length is : 39
# Aña
#   category :  Joyas y Relojes
# df_final length is : 39
# Aña
#   category :  Juegos y Juguetes
# df_final length is : 39
# Aña
#   category :  Libros, Revistas y Comics
# df_final length is : 39
# Aña
#   category :  Música, Películas y Series
# df_final length is : 39
# Aña
#   category :  Ropa y Accesorios
# df_final length is : 39
# Aña
#   category :  Salud y Equipamiento Médico
# df_final length is : 39
# Aña
#   category :  Servicios
# df_final length is : 39
# Aña
#   category :  Otras categorías
# df_final length is : 39
# Ver
#   category :  Accesorios para Vehículos
# df_final length is : 42
# Ver
#   category :  Alimentos y Bebidas
# df_final length is : 42
# Ver
#   category :  Animales y Mascotas
# df_final length is : 43
# Ver
#   category :  Antigüedades
# df_final length is : 43
# Ver
#   category :  Arte y Artesanías
# df_final length is : 43
# Ver
#   category :  Autos, Motos y Otros
# df_final length is : 43
# Ver
#   category :  Bebés
# df_final length is : 45
# Ver
#   category :  Belleza y Cuidado Personal
# df_final length is : 45
# Ver
#   category :  Cámaras y Accesorios
# df_final length is : 45
# Ver
#   category :  Celulares y Teléfonos
# df_final length is : 45
# Ver
#   category :  Coleccionables y Hobbies
# df_final length is : 45
# Ver
#   category :  Computación
# df_final length is : 45
# Ver
#   category :  Consolas y Videojuegos
# df_final length is : 45
# Ver
#   category :  Deportes y Fitness
# df_final length is : 48
# Ver
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 48
# Ver
#   category :  Electrónica, Audio y Video
# df_final length is : 48
# Ver
#   category :  Entradas para Eventos
# df_final length is : 48
# Ver
#   category :  Herramientas y Construcción
# df_final length is : 48
# Ver
#   category :  Hogar, Muebles y Jardín
# df_final length is : 50
# Ver
#   category :  Industrias y Oficinas
# df_final length is : 51
# Ver
#   category :  Inmuebles
# df_final length is : 51
# Ver
#   category :  Instrumentos Musicales
# df_final length is : 51
# Ver
#   category :  Joyas y Relojes
# df_final length is : 51
# Ver
#   category :  Juegos y Juguetes
# df_final length is : 52
# Ver
#   category :  Libros, Revistas y Comics
# df_final length is : 52
# Ver
#   category :  Música, Películas y Series
# df_final length is : 52
# Ver
#   category :  Ropa y Accesorios
# df_final length is : 53
# Ver
#   category :  Salud y Equipamiento Médico
# df_final length is : 53
# Ver
#   category :  Servicios
# df_final length is : 53
# Ver
#   category :  Otras categorías
# df_final length is : 53
# Opa
#   category :  Accesorios para Vehículos
# df_final length is : 53
# Opa
#   category :  Alimentos y Bebidas
# df_final length is : 53
# Opa
#   category :  Animales y Mascotas
# df_final length is : 53
# Opa
#   category :  Antigüedades
# df_final length is : 53
# Opa
#   category :  Arte y Artesanías
# df_final length is : 53
# Opa
#   category :  Autos, Motos y Otros
# df_final length is : 53
# Opa
#   category :  Bebés
# df_final length is : 53
# Opa
#   category :  Belleza y Cuidado Personal
# df_final length is : 53
# Opa
#   category :  Cámaras y Accesorios
# df_final length is : 53
# Opa
#   category :  Celulares y Teléfonos
# df_final length is : 53
# Opa
#   category :  Coleccionables y Hobbies
# df_final length is : 53
# Opa
#   category :  Computación
# df_final length is : 53
# Opa
#   category :  Consolas y Videojuegos
# df_final length is : 53
# Opa
#   category :  Deportes y Fitness
# df_final length is : 53
# Opa
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 53
# Opa
#   category :  Electrónica, Audio y Video
# df_final length is : 53
# Opa
#   category :  Entradas para Eventos
# df_final length is : 53
# Opa
#   category :  Herramientas y Construcción
# df_final length is : 53
# Opa
#   category :  Hogar, Muebles y Jardín
# df_final length is : 53
# Opa
#   category :  Industrias y Oficinas
# df_final length is : 53
# Opa
#   category :  Inmuebles
# df_final length is : 53
# Opa
#   category :  Instrumentos Musicales
# df_final length is : 53
# Opa
#   category :  Joyas y Relojes
# df_final length is : 53
# Opa
#   category :  Juegos y Juguetes
# df_final length is : 53
# Opa
#   category :  Libros, Revistas y Comics
# df_final length is : 53
# Opa
#   category :  Música, Películas y Series
# df_final length is : 53
# Opa
#   category :  Ropa y Accesorios
# df_final length is : 53
# Opa
#   category :  Salud y Equipamiento Médico
# df_final length is : 53
# Opa
#   category :  Servicios
# df_final length is : 53
# Opa
#   category :  Otras categorías
# df_final length is : 53
# Muí
#   category :  Accesorios para Vehículos
# df_final length is : 53
# Muí
#   category :  Alimentos y Bebidas
# df_final length is : 53
# Muí
#   category :  Animales y Mascotas
# df_final length is : 53
# Muí
#   category :  Antigüedades
# df_final length is : 53
# Muí
#   category :  Arte y Artesanías
# df_final length is : 53
# Muí
#   category :  Autos, Motos y Otros
# df_final length is : 53
# Muí
#   category :  Bebés
# df_final length is : 53
# Muí
#   category :  Belleza y Cuidado Personal
# df_final length is : 53
# Muí
#   category :  Cámaras y Accesorios
# df_final length is : 53
# Muí
#   category :  Celulares y Teléfonos
# df_final length is : 53
# Muí
#   category :  Coleccionables y Hobbies
# df_final length is : 53
# Muí
#   category :  Computación
# df_final length is : 53
# Muí
#   category :  Consolas y Videojuegos
# df_final length is : 53
# Muí
#   category :  Deportes y Fitness
# df_final length is : 53
# Muí
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 53
# Muí
#   category :  Electrónica, Audio y Video
# df_final length is : 53
# Muí
#   category :  Entradas para Eventos
# df_final length is : 53
# Muí
#   category :  Herramientas y Construcción
# df_final length is : 53
# Muí
#   category :  Hogar, Muebles y Jardín
# df_final length is : 53
# Muí
#   category :  Industrias y Oficinas
# df_final length is : 53
# Muí
#   category :  Inmuebles
# df_final length is : 53
# Muí
#   category :  Instrumentos Musicales
# df_final length is : 53
# Muí
#   category :  Joyas y Relojes
# df_final length is : 53
# Muí
#   category :  Juegos y Juguetes
# df_final length is : 53
# Muí
#   category :  Libros, Revistas y Comics
# df_final length is : 53
# Muí
#   category :  Música, Películas y Series
# df_final length is : 53
# Muí
#   category :  Ropa y Accesorios
# df_final length is : 53
# Muí
#   category :  Salud y Equipamiento Médico
# df_final length is : 53
# Muí
#   category :  Servicios
# df_final length is : 53
# Muí
#   category :  Otras categorías
# df_final length is : 53
# Yal
#   category :  Accesorios para Vehículos
# df_final length is : 53
# Yal
#   category :  Alimentos y Bebidas
# df_final length is : 53
# Yal
#   category :  Animales y Mascotas
# df_final length is : 53
# Yal
#   category :  Antigüedades
# df_final length is : 53
# Yal
#   category :  Arte y Artesanías
# df_final length is : 53
# Yal
#   category :  Autos, Motos y Otros
# df_final length is : 53
# Yal
#   category :  Bebés
# df_final length is : 53
# Yal
#   category :  Belleza y Cuidado Personal
# df_final length is : 53
# Yal
#   category :  Cámaras y Accesorios
# df_final length is : 53
# Yal
#   category :  Celulares y Teléfonos
# df_final length is : 53
# Yal
#   category :  Coleccionables y Hobbies
# df_final length is : 53
# Yal
#   category :  Computación
# df_final length is : 53
# Yal
#   category :  Consolas y Videojuegos
# df_final length is : 53
# Yal
#   category :  Deportes y Fitness
# df_final length is : 53
# Yal
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 53
# Yal
#   category :  Electrónica, Audio y Video
# df_final length is : 53
# Yal
#   category :  Entradas para Eventos
# df_final length is : 53
# Yal
#   category :  Herramientas y Construcción
# df_final length is : 53
# Yal
#   category :  Hogar, Muebles y Jardín
# df_final length is : 53
# Yal
#   category :  Industrias y Oficinas
# df_final length is : 53
# Yal
#   category :  Inmuebles
# df_final length is : 53
# Yal
#   category :  Instrumentos Musicales
# df_final length is : 53
# Yal
#   category :  Joyas y Relojes
# df_final length is : 53
# Yal
#   category :  Juegos y Juguetes
# df_final length is : 55
# Yal
#   category :  Libros, Revistas y Comics
# df_final length is : 55
# Yal
#   category :  Música, Películas y Series
# df_final length is : 55
# Yal
#   category :  Ropa y Accesorios
# df_final length is : 55
# Yal
#   category :  Salud y Equipamiento Médico
# df_final length is : 55
# Yal
#   category :  Servicios
# df_final length is : 55
# Yal
#   category :  Otras categorías
# df_final length is : 55
# Son
#   category :  Accesorios para Vehículos
# df_final length is : 55
# Son
#   category :  Alimentos y Bebidas
# df_final length is : 55
# Son
#   category :  Animales y Mascotas
# df_final length is : 55
# Son
#   category :  Antigüedades
# df_final length is : 55
# Son
#   category :  Arte y Artesanías
# df_final length is : 55
# Son
#   category :  Autos, Motos y Otros
# df_final length is : 55
# Son
#   category :  Bebés
# df_final length is : 55
# Son
#   category :  Belleza y Cuidado Personal
# df_final length is : 55
# Son
#   category :  Cámaras y Accesorios
# df_final length is : 55
# Son
#   category :  Celulares y Teléfonos
# df_final length is : 55
# Son
#   category :  Coleccionables y Hobbies
# df_final length is : 55
# Son
#   category :  Computación
# df_final length is : 55
# Son
#   category :  Consolas y Videojuegos
# df_final length is : 55
# Son
#   category :  Deportes y Fitness
# df_final length is : 55
# Son
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 55
# Son
#   category :  Electrónica, Audio y Video
# df_final length is : 55
# Son
#   category :  Entradas para Eventos
# df_final length is : 55
# Son
#   category :  Herramientas y Construcción
# df_final length is : 55
# Son
#   category :  Hogar, Muebles y Jardín
# df_final length is : 58
# Son
#   category :  Industrias y Oficinas
# df_final length is : 58
# Son
#   category :  Inmuebles
# df_final length is : 58
# Son
#   category :  Instrumentos Musicales
# df_final length is : 58
# Son
#   category :  Joyas y Relojes
# df_final length is : 58
# Son
#   category :  Juegos y Juguetes
# df_final length is : 59
# Son
#   category :  Libros, Revistas y Comics
# df_final length is : 59
# Son
#   category :  Música, Películas y Series
# df_final length is : 59
# Son
#   category :  Ropa y Accesorios
# df_final length is : 59
# Son
#   category :  Salud y Equipamiento Médico
# df_final length is : 59
# Son
#   category :  Servicios
# df_final length is : 59
# Son
#   category :  Otras categorías
# df_final length is : 59
# Ois
#   category :  Accesorios para Vehículos
# df_final length is : 59
# Ois
#   category :  Alimentos y Bebidas
# df_final length is : 59
# Ois
#   category :  Animales y Mascotas
# df_final length is : 59
# Ois
#   category :  Antigüedades
# df_final length is : 59
# Ois
#   category :  Arte y Artesanías
# df_final length is : 59
# Ois
#   category :  Autos, Motos y Otros
# df_final length is : 59
# Ois
#   category :  Bebés
# df_final length is : 59
# Ois
#   category :  Belleza y Cuidado Personal
# df_final length is : 59
# Ois
#   category :  Cámaras y Accesorios
# df_final length is : 59
# Ois
#   category :  Celulares y Teléfonos
# df_final length is : 59
# Ois
#   category :  Coleccionables y Hobbies
# df_final length is : 59
# Ois
#   category :  Computación
# df_final length is : 59
# Ois
#   category :  Consolas y Videojuegos
# df_final length is : 59
# Ois
#   category :  Deportes y Fitness
# df_final length is : 59
# Ois
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 59
# Ois
#   category :  Electrónica, Audio y Video
# df_final length is : 59
# Ois
#   category :  Entradas para Eventos
# df_final length is : 59
# Ois
#   category :  Herramientas y Construcción
# df_final length is : 59
# Ois
#   category :  Hogar, Muebles y Jardín
# df_final length is : 59
# Ois
#   category :  Industrias y Oficinas
# df_final length is : 59
# Ois
#   category :  Inmuebles
# df_final length is : 59
# Ois
#   category :  Instrumentos Musicales
# df_final length is : 59
# Ois
#   category :  Joyas y Relojes
# df_final length is : 59
# Ois
#   category :  Juegos y Juguetes
# df_final length is : 59
# Ois
#   category :  Libros, Revistas y Comics
# df_final length is : 59
# Ois
#   category :  Música, Películas y Series
# df_final length is : 59
# Ois
#   category :  Ropa y Accesorios
# df_final length is : 59
# Ois
#   category :  Salud y Equipamiento Médico
# df_final length is : 59
# Ois
#   category :  Servicios
# df_final length is : 59
# Ois
#   category :  Otras categorías
# df_final length is : 59
# Mam
#   category :  Accesorios para Vehículos
# df_final length is : 59
# Mam
#   category :  Alimentos y Bebidas
# df_final length is : 59
# Mam
#   category :  Animales y Mascotas
# df_final length is : 59
# Mam
#   category :  Antigüedades
# df_final length is : 59
# Mam
#   category :  Arte y Artesanías
# df_final length is : 59
# Mam
#   category :  Autos, Motos y Otros
# df_final length is : 59
# Mam
#   category :  Bebés
# df_final length is : 63
# Mam
#   category :  Belleza y Cuidado Personal
# df_final length is : 63
# Mam
#   category :  Cámaras y Accesorios
# df_final length is : 63
# Mam
#   category :  Celulares y Teléfonos
# df_final length is : 63
# Mam
#   category :  Coleccionables y Hobbies
# df_final length is : 63
# Mam
#   category :  Computación
# df_final length is : 63
# Mam
#   category :  Consolas y Videojuegos
# df_final length is : 67
# Mam
#   category :  Deportes y Fitness
# df_final length is : 68
# Mam
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 68
# Mam
#   category :  Electrónica, Audio y Video
# df_final length is : 68
# Mam
#   category :  Entradas para Eventos
# df_final length is : 68
# Mam
#   category :  Herramientas y Construcción
# df_final length is : 69
# Mam
#   category :  Hogar, Muebles y Jardín
# df_final length is : 70
# Mam
#   category :  Industrias y Oficinas
# df_final length is : 70
# Mam
#   category :  Inmuebles
# df_final length is : 70
# Mam
#   category :  Instrumentos Musicales
# df_final length is : 70
# Mam
#   category :  Joyas y Relojes
# df_final length is : 70
# Mam
#   category :  Juegos y Juguetes
# df_final length is : 74
# Mam
#   category :  Libros, Revistas y Comics
# df_final length is : 74
# Mam
#   category :  Música, Películas y Series
# df_final length is : 74
# Mam
#   category :  Ropa y Accesorios
# df_final length is : 75
# Mam
#   category :  Salud y Equipamiento Médico
# df_final length is : 75
# Mam
#   category :  Servicios
# df_final length is : 75
# Mam
#   category :  Otras categorías
# df_final length is : 75
# Era
#   category :  Accesorios para Vehículos
# df_final length is : 75
# Era
#   category :  Alimentos y Bebidas
# df_final length is : 75
# Era
#   category :  Animales y Mascotas
# df_final length is : 75
# Era
#   category :  Antigüedades
# df_final length is : 75
# Era
#   category :  Arte y Artesanías
# df_final length is : 75
# Era
#   category :  Autos, Motos y Otros
# df_final length is : 75
# Era
#   category :  Bebés
# df_final length is : 75
# Era
#   category :  Belleza y Cuidado Personal
# df_final length is : 76
# Era
#   category :  Cámaras y Accesorios
# df_final length is : 76
# Era
#   category :  Celulares y Teléfonos
# df_final length is : 77
# Era
#   category :  Coleccionables y Hobbies
# df_final length is : 77
# Era
#   category :  Computación
# df_final length is : 77
# Era
#   category :  Consolas y Videojuegos
# df_final length is : 77
# Era
#   category :  Deportes y Fitness
# df_final length is : 77
# Era
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 77
# Era
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Era
#   category :  Entradas para Eventos
# df_final length is : 79
# Era
#   category :  Herramientas y Construcción
# df_final length is : 79
# Era
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Era
#   category :  Industrias y Oficinas
# df_final length is : 79
# Era
#   category :  Inmuebles
# df_final length is : 79
# Era
#   category :  Instrumentos Musicales
# df_final length is : 79
# Era
#   category :  Joyas y Relojes
# df_final length is : 79
# Era
#   category :  Juegos y Juguetes
# df_final length is : 79
# Era
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Era
#   category :  Música, Películas y Series
# df_final length is : 79
# Era
#   category :  Ropa y Accesorios
# df_final length is : 79
# Era
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Era
#   category :  Servicios
# df_final length is : 79
# Era
#   category :  Otras categorías
# df_final length is : 79
# Obo
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Obo
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Obo
#   category :  Animales y Mascotas
# df_final length is : 79
# Obo
#   category :  Antigüedades
# df_final length is : 79
# Obo
#   category :  Arte y Artesanías
# df_final length is : 79
# Obo
#   category :  Autos, Motos y Otros
# df_final length is : 79
# Obo
#   category :  Bebés
# df_final length is : 79
# Obo
#   category :  Belleza y Cuidado Personal
# df_final length is : 79
# Obo
#   category :  Cámaras y Accesorios
# df_final length is : 79
# Obo
#   category :  Celulares y Teléfonos
# df_final length is : 79
# Obo
#   category :  Coleccionables y Hobbies
# df_final length is : 79
# Obo
#   category :  Computación
# df_final length is : 79
# Obo
#   category :  Consolas y Videojuegos
# df_final length is : 79
# Obo
#   category :  Deportes y Fitness
# df_final length is : 79
# Obo
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 79
# Obo
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Obo
#   category :  Entradas para Eventos
# df_final length is : 79
# Obo
#   category :  Herramientas y Construcción
# df_final length is : 79
# Obo
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Obo
#   category :  Industrias y Oficinas
# df_final length is : 79
# Obo
#   category :  Inmuebles
# df_final length is : 79
# Obo
#   category :  Instrumentos Musicales
# df_final length is : 79
# Obo
#   category :  Joyas y Relojes
# df_final length is : 79
# Obo
#   category :  Juegos y Juguetes
# df_final length is : 79
# Obo
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Obo
#   category :  Música, Películas y Series
# df_final length is : 79
# Obo
#   category :  Ropa y Accesorios
# df_final length is : 79
# Obo
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Obo
#   category :  Servicios
# df_final length is : 79
# Obo
#   category :  Otras categorías
# df_final length is : 79
# Aba
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Aba
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Aba
#   category :  Animales y Mascotas
# df_final length is : 79
# Aba
#   category :  Antigüedades
# df_final length is : 79
# Aba
#   category :  Arte y Artesanías
# df_final length is : 79
# Aba
#   category :  Autos, Motos y Otros
# df_final length is : 79
# Aba
#   category :  Bebés
# df_final length is : 79
# Aba
#   category :  Belleza y Cuidado Personal
# df_final length is : 79
# Aba
#   category :  Cámaras y Accesorios
# df_final length is : 79
# Aba
#   category :  Celulares y Teléfonos
# df_final length is : 79
# Aba
#   category :  Coleccionables y Hobbies
# df_final length is : 79
# Aba
#   category :  Computación
# df_final length is : 79
# Aba
#   category :  Consolas y Videojuegos
# df_final length is : 79
# Aba
#   category :  Deportes y Fitness
# df_final length is : 79
# Aba
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 79
# Aba
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Aba
#   category :  Entradas para Eventos
# df_final length is : 79
# Aba
#   category :  Herramientas y Construcción
# df_final length is : 79
# Aba
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Aba
#   category :  Industrias y Oficinas
# df_final length is : 79
# Aba
#   category :  Inmuebles
# df_final length is : 79
# Aba
#   category :  Instrumentos Musicales
# df_final length is : 79
# Aba
#   category :  Joyas y Relojes
# df_final length is : 79
# Aba
#   category :  Juegos y Juguetes
# df_final length is : 79
# Aba
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Aba
#   category :  Música, Películas y Series
# df_final length is : 79
# Aba
#   category :  Ropa y Accesorios
# df_final length is : 79
# Aba
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Aba
#   category :  Servicios
# df_final length is : 79
# Aba
#   category :  Otras categorías
# df_final length is : 79
# Fez
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Fez
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Fez
#   category :  Animales y Mascotas
# df_final length is : 79
# Fez
#   category :  Antigüedades
# df_final length is : 79
# Fez
#   category :  Arte y Artesanías
# df_final length is : 79
# Fez
#   category :  Autos, Motos y Otros
# df_final length is : 79
# Fez
#   category :  Bebés
# df_final length is : 79
# Fez
#   category :  Belleza y Cuidado Personal
# df_final length is : 79
# Fez
#   category :  Cámaras y Accesorios
# df_final length is : 79
# Fez
#   category :  Celulares y Teléfonos
# df_final length is : 79
# Fez
#   category :  Coleccionables y Hobbies
# df_final length is : 79
# Fez
#   category :  Computación
# df_final length is : 79
# Fez
#   category :  Consolas y Videojuegos
# df_final length is : 79
# Fez
#   category :  Deportes y Fitness
# df_final length is : 79
# Fez
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 79
# Fez
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Fez
#   category :  Entradas para Eventos
# df_final length is : 79
# Fez
#   category :  Herramientas y Construcción
# df_final length is : 79
# Fez
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Fez
#   category :  Industrias y Oficinas
# df_final length is : 79
# Fez
#   category :  Inmuebles
# df_final length is : 79
# Fez
#   category :  Instrumentos Musicales
# df_final length is : 79
# Fez
#   category :  Joyas y Relojes
# df_final length is : 79
# Fez
#   category :  Juegos y Juguetes
# df_final length is : 79
# Fez
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Fez
#   category :  Música, Películas y Series
# df_final length is : 79
# Fez
#   category :  Ropa y Accesorios
# df_final length is : 79
# Fez
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Fez
#   category :  Servicios
# df_final length is : 79
# Fez
#   category :  Otras categorías
# df_final length is : 79
# Íes
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Íes
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Íes
#   category :  Animales y Mascotas
# df_final length is : 79
# Íes
#   category :  Antigüedades
# df_final length is : 79
# Íes
#   category :  Arte y Artesanías
# df_final length is : 79
# Íes
#   category :  Autos, Motos y Otros
# df_final length is : 79
# Íes
#   category :  Bebés
# df_final length is : 79
# Íes
#   category :  Belleza y Cuidado Personal
# df_final length is : 79
# Íes
#   category :  Cámaras y Accesorios
# df_final length is : 79
# Íes
#   category :  Celulares y Teléfonos
# df_final length is : 79
# Íes
#   category :  Coleccionables y Hobbies
# df_final length is : 79
# Íes
#   category :  Computación
# df_final length is : 79
# Íes
#   category :  Consolas y Videojuegos
# df_final length is : 79
# Íes
#   category :  Deportes y Fitness
# df_final length is : 79
# Íes
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 79
# Íes
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Íes
#   category :  Entradas para Eventos
# df_final length is : 79
# Íes
#   category :  Herramientas y Construcción
# df_final length is : 79
# Íes
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Íes
#   category :  Industrias y Oficinas
# df_final length is : 79
# Íes
#   category :  Inmuebles
# df_final length is : 79
# Íes
#   category :  Instrumentos Musicales
# df_final length is : 79
# Íes
#   category :  Joyas y Relojes
# df_final length is : 79
# Íes
#   category :  Juegos y Juguetes
# df_final length is : 79
# Íes
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Íes
#   category :  Música, Películas y Series
# df_final length is : 79
# Íes
#   category :  Ropa y Accesorios
# df_final length is : 79
# Íes
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Íes
#   category :  Servicios
# df_final length is : 79
# Íes
#   category :  Otras categorías
# df_final length is : 79
# Ole
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Ole
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Ole
#   category :  Animales y Mascotas
# df_final length is : 79
# Ole
#   category :  Antigüedades
# df_final length is : 79
# Ole
#   category :  Arte y Artesanías
# df_final length is : 79
# Ole
#   category :  Autos, Motos y Otros
# df_final length is : 79
# Ole
#   category :  Bebés
# df_final length is : 79
# Ole
#   category :  Belleza y Cuidado Personal
# df_final length is : 79
# Ole
#   category :  Cámaras y Accesorios
# df_final length is : 79
# Ole
#   category :  Celulares y Teléfonos
# df_final length is : 79
# Ole
#   category :  Coleccionables y Hobbies
# df_final length is : 79
# Ole
#   category :  Computación
# df_final length is : 79
# Ole
#   category :  Consolas y Videojuegos
# df_final length is : 79
# Ole
#   category :  Deportes y Fitness
# df_final length is : 79
# Ole
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 79
# Ole
#   category :  Electrónica, Audio y Video
# df_final length is : 79
# Ole
#   category :  Entradas para Eventos
# df_final length is : 79
# Ole
#   category :  Herramientas y Construcción
# df_final length is : 79
# Ole
#   category :  Hogar, Muebles y Jardín
# df_final length is : 79
# Ole
#   category :  Industrias y Oficinas
# df_final length is : 79
# Ole
#   category :  Inmuebles
# df_final length is : 79
# Ole
#   category :  Instrumentos Musicales
# df_final length is : 79
# Ole
#   category :  Joyas y Relojes
# df_final length is : 79
# Ole
#   category :  Juegos y Juguetes
# df_final length is : 79
# Ole
#   category :  Libros, Revistas y Comics
# df_final length is : 79
# Ole
#   category :  Música, Películas y Series
# df_final length is : 79
# Ole
#   category :  Ropa y Accesorios
# df_final length is : 79
# Ole
#   category :  Salud y Equipamiento Médico
# df_final length is : 79
# Ole
#   category :  Servicios
# df_final length is : 79
# Ole
#   category :  Otras categorías
# df_final length is : 79
# Pum
#   category :  Accesorios para Vehículos
# df_final length is : 79
# Pum
#   category :  Alimentos y Bebidas
# df_final length is : 79
# Pum
#   category :  Animales y Mascotas
# df_final length is : 79
# Pum
#   category :  Antigüedades
# df_final length is : 80
# Pum
#   category :  Arte y Artesanías
# df_final length is : 80
# Pum
#   category :  Autos, Motos y Otros
# df_final length is : 80
# Pum
#   category :  Bebés
# df_final length is : 80
# Pum
#   category :  Belleza y Cuidado Personal
# df_final length is : 80
# Pum
#   category :  Cámaras y Accesorios
# df_final length is : 80
# Pum
#   category :  Celulares y Teléfonos
# df_final length is : 80
# Pum
#   category :  Coleccionables y Hobbies
# df_final length is : 80
# Pum
#   category :  Computación
# df_final length is : 80
# Pum
#   category :  Consolas y Videojuegos
# df_final length is : 80
# Pum
#   category :  Deportes y Fitness
# df_final length is : 80
# Pum
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 80
# Pum
#   category :  Electrónica, Audio y Video
# df_final length is : 80
# Pum
#   category :  Entradas para Eventos
# ...
# Oro
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 370
# Oro
#   category :  Electrónica, Audio y Video
# df_final length is : 370
# Oro
#   category :  Entradas para Eventos
# df_final length is : 370
# Oro
#   category :  Herramientas y Construcción
# df_final length is : 370
# Oro
#   category :  Hogar, Muebles y Jardín
# df_final length is : 380
# Oro
#   category :  Industrias y Oficinas
# df_final length is : 384
# Oro
#   category :  Inmuebles
# df_final length is : 384
# Oro
#   category :  Instrumentos Musicales
# df_final length is : 384
# Oro
#   category :  Joyas y Relojes
# df_final length is : 399
# Oro
#   category :  Juegos y Juguetes
# df_final length is : 399
# Oro
#   category :  Libros, Revistas y Comics
# df_final length is : 399
# Oro
#   category :  Música, Películas y Series
# df_final length is : 399
# Oro
#   category :  Ropa y Accesorios
# df_final length is : 399
# Oro
#   category :  Salud y Equipamiento Médico
# df_final length is : 399
# Oro
#   category :  Servicios
# df_final length is : 399
# Oro
#   category :  Otras categorías
# df_final length is : 399
# Bus
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Bus
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Bus
#   category :  Animales y Mascotas
# df_final length is : 401
# Bus
#   category :  Antigüedades
# df_final length is : 401
# Bus
#   category :  Arte y Artesanías
# df_final length is : 401
# Bus
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Bus
#   category :  Bebés
# df_final length is : 401
# Bus
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Bus
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Bus
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Bus
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Bus
#   category :  Computación
# df_final length is : 401
# Bus
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Bus
#   category :  Deportes y Fitness
# df_final length is : 401
# Bus
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Bus
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Bus
#   category :  Entradas para Eventos
# df_final length is : 401
# Bus
#   category :  Herramientas y Construcción
# df_final length is : 401
# Bus
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Bus
#   category :  Industrias y Oficinas
# df_final length is : 401
# Bus
#   category :  Inmuebles
# df_final length is : 401
# Bus
#   category :  Instrumentos Musicales
# df_final length is : 401
# Bus
#   category :  Joyas y Relojes
# df_final length is : 401
# Bus
#   category :  Juegos y Juguetes
# df_final length is : 401
# Bus
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Bus
#   category :  Música, Películas y Series
# df_final length is : 401
# Bus
#   category :  Ropa y Accesorios
# df_final length is : 401
# Bus
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Bus
#   category :  Servicios
# df_final length is : 401
# Bus
#   category :  Otras categorías
# df_final length is : 401
# Tup
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Tup
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Tup
#   category :  Animales y Mascotas
# df_final length is : 401
# Tup
#   category :  Antigüedades
# df_final length is : 401
# Tup
#   category :  Arte y Artesanías
# df_final length is : 401
# Tup
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Tup
#   category :  Bebés
# df_final length is : 401
# Tup
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Tup
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Tup
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Tup
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Tup
#   category :  Computación
# df_final length is : 401
# Tup
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Tup
#   category :  Deportes y Fitness
# df_final length is : 401
# Tup
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Tup
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Tup
#   category :  Entradas para Eventos
# df_final length is : 401
# Tup
#   category :  Herramientas y Construcción
# df_final length is : 401
# Tup
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Tup
#   category :  Industrias y Oficinas
# df_final length is : 401
# Tup
#   category :  Inmuebles
# df_final length is : 401
# Tup
#   category :  Instrumentos Musicales
# df_final length is : 401
# Tup
#   category :  Joyas y Relojes
# df_final length is : 401
# Tup
#   category :  Juegos y Juguetes
# df_final length is : 401
# Tup
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Tup
#   category :  Música, Películas y Series
# df_final length is : 401
# Tup
#   category :  Ropa y Accesorios
# df_final length is : 401
# Tup
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Tup
#   category :  Servicios
# df_final length is : 401
# Tup
#   category :  Otras categorías
# df_final length is : 401
# Uce
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Uce
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Uce
#   category :  Animales y Mascotas
# df_final length is : 401
# Uce
#   category :  Antigüedades
# df_final length is : 401
# Uce
#   category :  Arte y Artesanías
# df_final length is : 401
# Uce
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Uce
#   category :  Bebés
# df_final length is : 401
# Uce
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Uce
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Uce
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Uce
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Uce
#   category :  Computación
# df_final length is : 401
# Uce
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Uce
#   category :  Deportes y Fitness
# df_final length is : 401
# Uce
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Uce
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Uce
#   category :  Entradas para Eventos
# df_final length is : 401
# Uce
#   category :  Herramientas y Construcción
# df_final length is : 401
# Uce
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Uce
#   category :  Industrias y Oficinas
# df_final length is : 401
# Uce
#   category :  Inmuebles
# df_final length is : 401
# Uce
#   category :  Instrumentos Musicales
# df_final length is : 401
# Uce
#   category :  Joyas y Relojes
# df_final length is : 401
# Uce
#   category :  Juegos y Juguetes
# df_final length is : 401
# Uce
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Uce
#   category :  Música, Películas y Series
# df_final length is : 401
# Uce
#   category :  Ropa y Accesorios
# df_final length is : 401
# Uce
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Uce
#   category :  Servicios
# df_final length is : 401
# Uce
#   category :  Otras categorías
# df_final length is : 401
# Uvi
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Uvi
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Uvi
#   category :  Animales y Mascotas
# df_final length is : 401
# Uvi
#   category :  Antigüedades
# df_final length is : 401
# Uvi
#   category :  Arte y Artesanías
# df_final length is : 401
# Uvi
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Uvi
#   category :  Bebés
# df_final length is : 401
# Uvi
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Uvi
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Uvi
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Uvi
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Uvi
#   category :  Computación
# df_final length is : 401
# Uvi
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Uvi
#   category :  Deportes y Fitness
# df_final length is : 401
# Uvi
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Uvi
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Uvi
#   category :  Entradas para Eventos
# df_final length is : 401
# Uvi
#   category :  Herramientas y Construcción
# df_final length is : 401
# Uvi
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Uvi
#   category :  Industrias y Oficinas
# df_final length is : 401
# Uvi
#   category :  Inmuebles
# df_final length is : 401
# Uvi
#   category :  Instrumentos Musicales
# df_final length is : 401
# Uvi
#   category :  Joyas y Relojes
# df_final length is : 401
# Uvi
#   category :  Juegos y Juguetes
# df_final length is : 401
# Uvi
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Uvi
#   category :  Música, Películas y Series
# df_final length is : 401
# Uvi
#   category :  Ropa y Accesorios
# df_final length is : 401
# Uvi
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Uvi
#   category :  Servicios
# df_final length is : 401
# Uvi
#   category :  Otras categorías
# df_final length is : 401
# Cui
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Cui
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Cui
#   category :  Animales y Mascotas
# df_final length is : 401
# Cui
#   category :  Antigüedades
# df_final length is : 401
# Cui
#   category :  Arte y Artesanías
# df_final length is : 401
# Cui
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Cui
#   category :  Bebés
# df_final length is : 401
# Cui
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Cui
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Cui
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Cui
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Cui
#   category :  Computación
# df_final length is : 401
# Cui
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Cui
#   category :  Deportes y Fitness
# df_final length is : 401
# Cui
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Cui
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Cui
#   category :  Entradas para Eventos
# df_final length is : 401
# Cui
#   category :  Herramientas y Construcción
# df_final length is : 401
# Cui
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Cui
#   category :  Industrias y Oficinas
# df_final length is : 401
# Cui
#   category :  Inmuebles
# df_final length is : 401
# Cui
#   category :  Instrumentos Musicales
# df_final length is : 401
# Cui
#   category :  Joyas y Relojes
# df_final length is : 401
# Cui
#   category :  Juegos y Juguetes
# df_final length is : 401
# Cui
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Cui
#   category :  Música, Películas y Series
# df_final length is : 401
# Cui
#   category :  Ropa y Accesorios
# df_final length is : 401
# Cui
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Cui
#   category :  Servicios
# df_final length is : 401
# Cui
#   category :  Otras categorías
# df_final length is : 401
# Pis
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Pis
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Pis
#   category :  Animales y Mascotas
# df_final length is : 401
# Pis
#   category :  Antigüedades
# df_final length is : 401
# Pis
#   category :  Arte y Artesanías
# df_final length is : 401
# Pis
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Pis
#   category :  Bebés
# df_final length is : 401
# Pis
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Pis
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Pis
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Pis
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Pis
#   category :  Computación
# df_final length is : 401
# Pis
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Pis
#   category :  Deportes y Fitness
# df_final length is : 401
# Pis
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Pis
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Pis
#   category :  Entradas para Eventos
# df_final length is : 401
# Pis
#   category :  Herramientas y Construcción
# df_final length is : 401
# Pis
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Pis
#   category :  Industrias y Oficinas
# df_final length is : 401
# Pis
#   category :  Inmuebles
# df_final length is : 401
# Pis
#   category :  Instrumentos Musicales
# df_final length is : 401
# Pis
#   category :  Joyas y Relojes
# df_final length is : 401
# Pis
#   category :  Juegos y Juguetes
# df_final length is : 401
# Pis
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Pis
#   category :  Música, Películas y Series
# df_final length is : 401
# Pis
#   category :  Ropa y Accesorios
# df_final length is : 401
# Pis
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Pis
#   category :  Servicios
# df_final length is : 401
# Pis
#   category :  Otras categorías
# df_final length is : 401
# Uvi
#   category :  Accesorios para Vehículos
# df_final length is : 401
# Uvi
#   category :  Alimentos y Bebidas
# df_final length is : 401
# Uvi
#   category :  Animales y Mascotas
# df_final length is : 401
# Uvi
#   category :  Antigüedades
# df_final length is : 401
# Uvi
#   category :  Arte y Artesanías
# df_final length is : 401
# Uvi
#   category :  Autos, Motos y Otros
# df_final length is : 401
# Uvi
#   category :  Bebés
# df_final length is : 401
# Uvi
#   category :  Belleza y Cuidado Personal
# df_final length is : 401
# Uvi
#   category :  Cámaras y Accesorios
# df_final length is : 401
# Uvi
#   category :  Celulares y Teléfonos
# df_final length is : 401
# Uvi
#   category :  Coleccionables y Hobbies
# df_final length is : 401
# Uvi
#   category :  Computación
# df_final length is : 401
# Uvi
#   category :  Consolas y Videojuegos
# df_final length is : 401
# Uvi
#   category :  Deportes y Fitness
# df_final length is : 401
# Uvi
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 401
# Uvi
#   category :  Electrónica, Audio y Video
# df_final length is : 401
# Uvi
#   category :  Entradas para Eventos
# df_final length is : 401
# Uvi
#   category :  Herramientas y Construcción
# df_final length is : 401
# Uvi
#   category :  Hogar, Muebles y Jardín
# df_final length is : 401
# Uvi
#   category :  Industrias y Oficinas
# df_final length is : 401
# Uvi
#   category :  Inmuebles
# df_final length is : 401
# Uvi
#   category :  Instrumentos Musicales
# df_final length is : 401
# Uvi
#   category :  Joyas y Relojes
# df_final length is : 401
# Uvi
#   category :  Juegos y Juguetes
# df_final length is : 401
# Uvi
#   category :  Libros, Revistas y Comics
# df_final length is : 401
# Uvi
#   category :  Música, Películas y Series
# df_final length is : 401
# Uvi
#   category :  Ropa y Accesorios
# df_final length is : 401
# Uvi
#   category :  Salud y Equipamiento Médico
# df_final length is : 401
# Uvi
#   category :  Servicios
# df_final length is : 401
# Uvi
#   category :  Otras categorías
# df_final length is : 401
# Chin
#   category :  Accesorios para Vehículos
# df_final length is : 402
# Chin
#   category :  Alimentos y Bebidas
# df_final length is : 402
# Chin
#   category :  Animales y Mascotas
# df_final length is : 403
# Chin
#   category :  Antigüedades
# df_final length is : 403
# Chin
#   category :  Arte y Artesanías
# df_final length is : 405
# Chin
#   category :  Autos, Motos y Otros
# df_final length is : 405
# Chin
#   category :  Bebés
# df_final length is : 405
# Chin
#   category :  Belleza y Cuidado Personal
# df_final length is : 408
# Chin
#   category :  Cámaras y Accesorios
# df_final length is : 408
# Chin
#   category :  Celulares y Teléfonos
# df_final length is : 408
# Chin
#   category :  Coleccionables y Hobbies
# df_final length is : 408
# Chin
#   category :  Computación
# df_final length is : 408
# Chin
#   category :  Consolas y Videojuegos
# df_final length is : 408
# Chin
#   category :  Deportes y Fitness
# df_final length is : 408
# Chin
#   category :  Electrodomésticos y Aires Ac.
# df_final length is : 408
# Chin
#   category :  Electrónica, Audio y Video
# df_final length is : 408
# Chin
#   category :  Entradas para Eventos
# df_final length is : 408
# Chin
#   category :  Herramientas y Construcción
# df_final length is : 410
# Chin
#   category :  Hogar, Muebles y Jardín
# df_final length is : 411
# Chin
#   category :  Industrias y Oficinas
# df_final length is : 412
# Chin
#   category :  Inmuebles
# df_final length is : 412
# Chin
#   category :  Instrumentos Musicales
# df_final length is : 412
# Chin
#   category :  Joyas y Relojes
# df_final length is : 412
# Chin
#   category :  Juegos y Juguetes
# df_final length is : 412
# Chin
#   category :  Libros, Revistas y Comics

# %%
display(HTML(df_final.sort_values('total',ascending=False).to_html()))

# %%
df_final = df_final.sort_values('total',ascending=False)
df_final.iloc[:10,:]

# %% [markdown]
# Categories:
#   {
#     "id": "MLA5725",
#     "name": "Accesorios para Vehículos"
#   },
#   {
#     "id": "MLA1403",
#     "name": "Alimentos y Bebidas"
#   },
#   {
#     "id": "MLA1071",
#     "name": "Animales y Mascotas"
#   },
#   {
#     "id": "MLA1367",
#     "name": "Antigüedades"
#   },
#   {
#     "id": "MLA1368",
#     "name": "Arte y Artesanías"
#   },
#   {
#     "id": "MLA1743",
#     "name": "Autos, Motos y Otros"
#   },
#   {
#     "id": "MLA1384",
#     "name": "Bebés"
#   },
#   {
#     "id": "MLA1246",
#     "name": "Belleza y Cuidado Personal"
#   },
#   {
#     "id": "MLA1039",
#     "name": "Cámaras y Accesorios"
#   },
#   {
#     "id": "MLA1051",
#     "name": "Celulares y Teléfonos"
#   },
#   {
#     "id": "MLA1798",
#     "name": "Coleccionables y Hobbies"
#   },
#   {
#     "id": "MLA1648",
#     "name": "Computación"
#   },
#   {
#     "id": "MLA1144",
#     "name": "Consolas y Videojuegos"
#   },
#   {
#     "id": "MLA1276",
#     "name": "Deportes y Fitness"
#   },
#   {
#     "id": "MLA5726",
#     "name": "Electrodomésticos y Aires Ac."
#   },
#   {
#     "id": "MLA1000",
#     "name": "Electrónica, Audio y Video"
#   },
#   {
#     "id": "MLA2547",
#     "name": "Entradas para Eventos"
#   },
#   {
#     "id": "MLA407134",
#     "name": "Herramientas y Construcción"
#   },
#   {
#     "id": "MLA1574",
#     "name": "Hogar, Muebles y Jardín"
#   },
#   {
#     "id": "MLA1499",
#     "name": "Industrias y Oficinas"
#   },
#   {
#     "id": "MLA1459",
#     "name": "Inmuebles"
#   },
#   {
#     "id": "MLA1182",
#     "name": "Instrumentos Musicales"
#   },
#   {
#     "id": "MLA3937",
#     "name": "Joyas y Relojes"
#   },
#   {
#     "id": "MLA1132",
#     "name": "Juegos y Juguetes"
#   },
#   {
#     "id": "MLA3025",
#     "name": "Libros, Revistas y Comics"
#   },
#   {
#     "id": "MLA1168",
#     "name": "Música, Películas y Series"
#   },
#   {
#     "id": "MLA1430",
#     "name": "Ropa y Accesorios"
#   },
#   {
#     "id": "MLA409431",
#     "name": "Salud y Equipamiento Médico"
#   },
#   {
#     "id": "MLA1540",
#     "name": "Servicios"
#   },
#   {
#     "id": "MLA1953",
#     "name": "Otras categorías"
